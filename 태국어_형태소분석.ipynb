# %%
from pythainlp import word_tokenize, Tokenizer

from pythainlp.util import find_keyword


f = open('th2.txt','r',encoding='UTF8')

data=  f.read()

f.close



token =word_tokenize(data, keep_whitespace=False)

find_keyword(token, min_len=1)
# Out:
# {'Mention': 1,
#  'Title': 1,
#  '\n': 2000,
#  '#': 5225,
#  '🍇': 23,
#  'Fairly': 12,
#  'Kiss': 12,
#  'Collagen': 14,
#  '⛄️': 12,
#  '+': 275,
#  'ฟรี': 173,
#  'ไฟเบอร์': 11,
#  'เกาหลี': 1106,
#  'เซ': 239,
#  'รั่ม': 180,
#  'innisfree': 948,
#  '💕': 60,
#  'โป': 30,
#  'รดี': 31,
#  'ดี': 409,
#  'ตละ': 23,
#  '❗️': 27,
#  '500': 54,
#  'EMS': 57,
#  'วิตามิน': 54,
#  'ซี': 64,
#  'อึน': 17,
#  'ดัน': 18,
#  'howtoperfact': 112,
#  'howtobeauty': 134,
#  'คอลลาเจน': 39,
#  'บอกต่อ': 269,
#  'ของดี': 66,
#  '#คสอ': 173,
#  'ขาว': 32,
#  'kiehl': 85,
#  '’': 252,
#  's': 427,
#  'calendula': 29,
#  'toner': 31,
#  'ตัว': 249,
#  'ฮิต': 15,
#  'ขวด': 78,
#  'ยักษ์': 1,
#  'ครึ่ง': 3,
#  'ลิตร': 2,
#  'า': 34,
#  '2,050': 1,
#  '฿': 249,
#  'ปกติ': 62,
#  '2,5': 1,
#  '++': 13,
#  'cotton': 13,
#  'ink': 12,
#  'no': 19,
#  '.': 865,
#  '6': 80,
#  '1': 569,
#  '200': 47,
#  'dark': 43,
#  'spot': 51,
#  'กก': 168,
#  'ปริมาณ': 3,
#  'รูป': 34,
#  '990': 10,
#  '3': 174,
# ...

# %%
# Out:
#   File "<ipython-input-3-2417895a3bb1>", line 3
#     rank(token)
#        ^
# IndentationError: expected an indented block
